# %% [markdown]
# # LATIHAN GC 1

# %% [markdown]
# ## INTRODUCTION
#
# - Nama:
# - Batch:
#
# Pada notebook ini akan dilakukan proses analisis...
#
# Objective:
# - mengetahui tingkat ....

# %% [markdown]
# ## IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## DATA LOADING AND OVERVIEW

# %%
# skema 1 - import dari local
pd.read_csv(r'C:\Users\Rafif\Desktop\mentoring\dataset\nbaallelo.csv')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
# skema 2 - menggunakan separator berbeda
pd.read_csv('coba.csv', sep=';')
# Out:
#    kolom1  kolom2  kolom3
# 0       1      40      23
# 1       2     434      54
# 2       3      44      90
# 3       4      60      81

# %%
# load data
df = pd.read_csv('dataset/nbaallelo.csv')

# %%
# menampilkan 5 data teratas
df.head()
# df.tail()
# df.sample(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
# melihat kelengkapan entry dan tipe data masing-masing kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# berdasarkan overview, diketahui:
# - ...
# - ...
# - ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
# pemanggilan kolom
df['team_id']
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
# pemanggilan multiple kolom
df[['team_id', 'fran_id']]
# Out:
#        team_id    fran_id
# 0          TRH    Huskies
# 1          NYK     Knicks
# 2          CHS      Stags
# 3          NYK     Knicks
# 4          DTF    Falcons
# ...        ...        ...
# 126309     CLE  Cavaliers
# 126310     GSW   Warriors
# 126311     CLE  Cavaliers
# 126312     CLE  Cavaliers
# 126313     GSW   Warriors
#
# [126314 rows x 2 columns]

# %%
df['team_id'].unique()
# Out:
# array(['TRH', 'NYK', 'CHS', 'DTF', 'WSC', 'BOS', 'PRO', 'PIT', 'STB',
#        'CLR', 'PHW', 'BLB', 'INJ', 'FTW', 'MNL', 'ROC', 'TRI', 'DNN',
#        'INO', 'SHE', 'WAT', 'AND', 'SYR', 'MLH', 'STL', 'DET', 'CIN',
#        'LAL', 'CHP', 'CHZ', 'SFW', 'BAL', 'PHI', 'CHI', 'SEA', 'OAK',
#        'ANA', 'SDR', 'KEN', 'INA', 'DNR', 'DLC', 'HSM', 'NOB', 'MNM',
#        'NJA', 'PTP', 'ATL', 'MIL', 'PHO', 'NYA', 'MMF', 'MNP', 'LAS',
#        'CAR', 'WSA', 'BUF', 'CLE', 'UTS', 'FLO', 'PTC', 'POR', 'VIR',
#        'TEX', 'MMP', 'HOU', 'GSW', 'KCO', 'MMT', 'SDA', 'CAP', 'SAA',
#        'NOJ', 'DNA', 'SSL', 'MMS', 'WSB', 'KCK', 'SDS', 'IND', 'NYN',
#        'DEN', 'SAS', 'NJN', 'SDC', 'UTA', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'VAN', 'TOR', 'WAS', 'MEM', 'NOH', 'CHA',
#        'NOK', 'OKC', 'BRK', 'NOP', 'CHO'], dtype=object)

# %%
df['team_id'].nunique()
# Out:
# 104

# %%
df['team_id'].value_counts().head()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %%
df['fran_id'].value_counts().head()
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %% [markdown]
# There is inconsistency between the results of ....

# %%
df.loc[df['fran_id']=='Lakers', :]['team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['fran_id']=='Lakers', 'team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['fran_id']=='Lakers', ['fran_id', 'team_id']]['team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
# .loc
# df.loc[ 0:5, :] #pemanggilan range

df.loc[ [1,7,6,14,99,2001], :] # baris spesifik multiple
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1             1  194611010TRH   NBA        1     1947   11/1/1946           1
# 7             4  194611020PRO   NBA        0     1947   11/2/1946           1
# 6             4  194611020PRO   NBA        1     1947   11/2/1946           1
# 14            8  194611050BOS   NBA        0     1947   11/5/1946           2
# 99           50  194611250PIT   NBA        0     1947  11/25/1946          10
# 2001       1001  194911150INO   NBA        0     1950  11/15/1949           8
#
#       is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 1               0     NYK        Knicks  ...  41.705170     TRH       Huskies
# 7               0     PRO  Steamrollers  ...  41.540619     BOS       Celtics
# 6               0     BOS       Celtics  ...  40.459381     PRO  Steamrollers
# 14              0     BOS       Celtics  ...  39.785030     CHS         Stags
# ...

# %%
a = df.iloc[ 1:5, :]
b = df.iloc[ 100:110, :]

pd.concat((a,b), axis=0)
# Out:
#      gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1            1  194611010TRH   NBA        1     1947   11/1/1946           1
# 2            2  194611020CHS   NBA        0     1947   11/2/1946           1
# 3            2  194611020CHS   NBA        1     1947   11/2/1946           2
# 4            3  194611020DTF   NBA        0     1947   11/2/1946           1
# 100         51  194611260DTF   NBA        0     1947  11/26/1946          11
# 101         51  194611260DTF   NBA        1     1947  11/26/1946           8
# 102         52  194611260GSW   NBA        0     1947  11/26/1946           5
# 103         52  194611260GSW   NBA        1     1947  11/26/1946          11
# 104         53  194611260TRH   NBA        0     1947  11/26/1946          11
# 105         53  194611260TRH   NBA        1     1947  11/26/1946          10
# 106         54  194611270NYK   NBA        1     1947  11/27/1946          11
# ...

# %% [markdown]
# ### Query

# %%
df.shape
# Out:
# (126314, 23)

# %%
df[(df['fran_id'] == 'Lakers') &          # melihat histori pertandingan lakers
   (df['year_id'] >= 2005) &              # dari tahun 2005
   (df['year_id'] <= 2010) &              # sampai 2010
   (df['opp_fran'] == 'Hawks') &          # melawan hawks
   (df['game_location'] == 'H')]          # di kandang lakers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 97969       48985  200411070LAL   NBA        0     2005  11/7/2004
# 102055      51028  200602150LAL   NBA        0     2006  2/15/2006
# 103708      51855  200612080LAL   NBA        0     2007  12/8/2006
# 107332      53667  200802190LAL   NBA        0     2008  2/19/2008
# 109983      54992  200902170LAL   NBA        0     2009  2/17/2009
# 111113      55557  200911010LAL   NBA        0     2010  11/1/2009
#
#         seasongame  is_playoffs team_id fran_id  ...  win_equiv  opp_id  \
# 97969            4            0     LAL  Lakers  ...  51.604019     ATL
# 102055          52            0     LAL  Lakers  ...  41.988670     ATL
# 103708          19            0     LAL  Lakers  ...  46.222126     ATL
# 107332          53            0     LAL  Lakers  ...  57.346104     ATL
# 109983          53            0     LAL  Lakers  ...  62.663246     ATL
# ...

# %%
df[(df['fran_id'] == 'Lakers') &         
   (df['year_id'] >= 2005) &             
   (df['year_id'] <= 2010) &              
   (df['opp_fran'] == 'Hawks') &         
   (df['game_location'] == 'H')][['year_id', 'fran_id', 'pts', 'opp_pts', 'opp_fran']]
# Out:
#         year_id fran_id  pts  opp_pts opp_fran
# 97969      2005  Lakers  106       90    Hawks
# 102055     2006  Lakers  110      114    Hawks
# 103708     2007  Lakers  106       95    Hawks
# 107332     2008  Lakers  122       93    Hawks
# 109983     2009  Lakers   96       83    Hawks
# 111113     2010  Lakers  118      110    Hawks

# %% [markdown]
# ## Group by and Aggregation

# %%
df.groupby('game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
# simulasi
grup = df.groupby('game_location')
grup

# %%
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
df.groupby('game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
# klub mana yang sering menang? -> frekuensi
df.groupby(['fran_id', 'game_result'])[['game_id']].count().reset_index().sort_values(by='game_id', ascending=False)

# %%
# klub mana yang sering menang? -> frekuensi
# melawan celtics
# semenjak 1996
df[(df['game_result']=='W') &
   (df['year_id'] > 1995) &
   (df['opp_fran'] == 'Celtics')].groupby('fran_id')[['team_id']].count().sort_values(by='team_id', ascending=False)

# %% [markdown]
# ## Cleaning/Manipulating Coloumn

# %%
nba = df.copy()

# %%
nba.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...   40.29483     NYK    Knicks       68
# 1            0     NYK   Knicks  ...   41.70517     TRH   Huskies       66
#
#   opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0    1300.0  1306.7233              H            L  0.640065   NaN
# 1    1300.0  1293.2767              A            W  0.359935   NaN
#
# [2 rows x 23 columns]

# %%
# simpan perubahan dengan inplace=True
nba.drop(columns=['opp_elo_i', 'opp_elo_n'], inplace=True)

# %%
# create new columns
nba['selisih'] = nba['pts'] - nba['opp_pts']

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...      elo_n  win_equiv  opp_id  opp_fran  \
# 0            0     TRH  Huskies  ...  1293.2767  40.294830     NYK    Knicks
# 1            0     NYK   Knicks  ...  1306.7233  41.705170     TRH   Huskies
# 2            0     CHS    Stags  ...  1309.6521  42.012257     NYK    Knicks
# 3            0     NYK   Knicks  ...  1297.0712  40.692783     CHS     Stags
# 4            0     DTF  Falcons  ...  1279.6189  38.864048     WSC  Capitols
#
# ...

# %%
# Celtics
# rata-rata poin tahunan season 2010 - 2015
nba[(nba['fran_id'] == 'Celtics') &
    (nba['year_id'] >=2010) &
    (nba['year_id'] <= 2015)].groupby('year_id')[['pts']].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
# Celtics
# rata-rata poin tahunan season 2010 - 2015
nba[(nba['fran_id'] == 'Celtics') &
    (nba['year_id'] >=2010) &
    (nba['year_id'] <= 2015)].groupby('year_id')[['pts']].mean().reset_index().plot(kind='bar', x='year_id', y='pts')
# Out:
# <AxesSubplot:>

# %%
# Celtics
# rata-rata poin tahunan season 2010 - 2015
preprocess = nba[(nba['fran_id'] == 'Celtics') &
                (nba['year_id'] >=2010) &
                (nba['year_id'] <= 2015)].groupby('year_id')[['pts']].mean().reset_index()

preprocess.plot(kind='bar', x='year_id', y='pts')
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
#if statement
if False:
    print('kondisi true')
    print('oke')

# %%
nilai = 70

if nilai > 70:
    print('lulus')
    print('good job')
elif nilai == 70:
    print('nilai pas')
    print('lulus')
else:
    print('tidak lulus')
# Out:
# nilai pas
# lulus

# %%
nama = 'bogor'

print(nama)
print(f'{nama} sangat nyaman')
print('oke')

# %%
lists = ['jakarta', 'bandung', 'medan', 'denpasar']

for nama in lists:
    print(nama)
    print(f'{nama} sangat nyaman')
    print('oke')

# %%
range(0, len(nba))
# Out:
# range(0, 126314)

# %%
nba.loc[0:4, 'team_id':]
# Out:
#   team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  opp_fran  \
# 0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK    Knicks
# 1     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH   Huskies
# 2     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK    Knicks
# 3     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS     Stags
# 4     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC  Capitols
#
#    opp_pts game_location game_result  forecast notes  selisih
# 0       68             H           L  0.640065   NaN       -2
# 1       66             A           W  0.359935   NaN        2
# 2       47             H           W  0.631101   NaN       16
# 3       63             A           L  0.368899   NaN      -16
# 4       50             H           L  0.640065   NaN      -17

# %%
idx = 4
pts = nba.iloc[idx, 10]
opp_pts = nba.iloc[idx, 16]
print(pts)
print(opp_pts)
# Out:
# 33
# 50

# %%
lists = []

# %%
lists.append(50)

lists
# Out:
# [1, 90, 50]

# %%
# selisihkan nilai di kolom pts dan opp_pts
# jika > 0 maka hasilnya menang
# jika < 0 maka hasilnya kalah
# jika == 0 maka seri
# buat kolom baru berdasarkan hasil
lists_penampung = []

for idx in range(0, len(nba)):
    selisih = nba.iloc[idx, 10] - nba.iloc[idx, 16]
    if selisih > 0:
        lists_penampung.append('menang')
    elif selisih < 0:
        lists_penampung.append('kalah')
    else:
        lists_penampung.append('seri')

nba['hasil'] = lists_penampung

# %%
pengecekan(0)
# Out:
# 'seri'

# %%
# selisihkan nilai di kolom pts dan opp_pts
# jika > 0 maka hasilnya menang
# jika < 0 maka hasilnya kalah
# jika == 0 maka seri
# buat kolom baru berdasarkan hasil

# function
def pengecekan(selisih):
    if selisih > 0:
        hasil = 'menang'
    elif selisih < 0:
        hasil = 'kalah'
    else:
        hasil = 'seri'
    
    return hasil

lists_penampung = []

# looping
for idx in range(0, len(nba)):
    selisih = nba.iloc[idx, 10] - nba.iloc[idx, 16]
    hasil = pengecekan(selisih)

    lists_penampung.append(hasil)

nba['hasil_2'] = lists_penampung

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...
